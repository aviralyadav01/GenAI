# %%
#1st load the document which is to be divided into chunks 
# ye document load hoga as a default type of DOCUMENTS 
from langchain_docling.loader import DoclingLoader
FILE_PATH= "data.txt"
loader = DoclingLoader(file_path = FILE_PATH)
doc = loader.load()
doc

# %%
#text splitter 
#using RECURSIVE CHARACTER TEXT SPLITTER 
from langchain_text_splitters import RecursiveCharacterTextSplitter

with open("data.txt") as f:
    data = f.read()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 50 ,
    chunk_overlap = 10, )
text = text_splitter.create_documents([data])
text
# Out:
# [Document(metadata={}, page_content='Ye normal DoclingLoader use karte waqt nahi aani'),
#  Document(metadata={}, page_content='nahi aani chahiye.'),
#  Document(metadata={}, page_content='Is warning ka matlab hai ki Docling external'),
#  Document(metadata={}, page_content='external plugin system ko load karne ki koshish'),
#  Document(metadata={}, page_content='koshish ho rahi hai, lekin'),
#  Document(metadata={}, page_content='lekin allow_external_plugins=False hai.'),
#  Document(metadata={}, page_content='hai. Third-party plugins ko use karna ho tab ise'),
#  Document(metadata={}, page_content='tab ise enable kiya jata hai. Normal'),
#  Document(metadata={}, page_content='Normal DoclingLoader ke liye iski zarurat nahi'),
#  Document(metadata={}, page_content='nahi hoti.'),
#  Document(metadata={}, page_content='Mujhe lagta hai tumne inme se koi cheez ki hai:'),
#  Document(metadata={}, page_content='docling CLI use kiya.'),
#  Document(metadata={}, page_content='Ya direct docling package ki plugin configuration'),
#  Document(metadata={}, page_content='use kar rahe ho.'),
#  Document(metadata={}, page_content='Ya kisi tutorial ka code chalaya jo external'),
#  Document(metadata={}, page_content='external plugins enable karna chahta hai.'),
#  Document(metadata={}, page_content='Ek kaam karo'),
#  Document(metadata={}, page_content='Mujhe ye 3 cheezein bhej do:'),
#  Document(metadata={}, page_content='requirements.txt'),
#  Document(metadata={}, page_content='Wo code jahan DoclingLoader use kar rahe ho.'),
#  Document(metadata={}, page_content='Poora traceback (sirf warning nahi, poora'),
#  Document(metadata={}, page_content='poora terminal output).'),
#  Document(metadata={}, page_content='Main 1 minute me bata dunga ki issue'),
#  Document(metadata={}, page_content='ki issue configuration ka hai, version mismatch'),
#  Document(metadata={}, page_content='mismatch ka hai, ya installation ka')]

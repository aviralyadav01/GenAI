# %%
# loading env things
import os
from dotenv import load_dotenv
load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ['']

# %%
# setting up groq LLM
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
    max_tokens=None,
)

llm.invoke("what is ai in 10 worlds") The content I can just go ahead and write result of content. Okay, so here is my output. Okay, AI message is not susceptible. Let's see what is an error result content is equal to generative AI. So here is my output that I'm able to get. Okay, let's see we will try to I'll also see why we get it but the sense sometime because I really need to show you some very, very important thing. So let me do one thing, let me just go back to my browser or let me show you this. Okay, just a second I will just go to my browser over here. Now inside this browser let me just go to my lines. Okay, now if I go ahead and click on the project so here you can see Gen AI app to open AI, right? And here if you go ahead and see there are two chat how beautifully everything is basically getting tracked in this. particular announcement now I hope everybody is able to understand why length right Because if you see the entire ecosystem langsmith is a uniform DevOps platform for developing collaborative testing and monitoring application that is the most amazing and right now here you can see right and now let's go ahead and do one thing let's click on this request so here you'll be able to see what is the human feedback that was given and what is the output that we got right everything is basically getting displayed how much delay is basically happening right how much delay latency right tokens and it also probably suggests how much cost it is basically taking based on the token size right so three sixty four ninety four this much cost has basically incurred in my open AI right and this is how beautifully we are able to develop the cent right now according to the next step over here you can see that I have actually displayed the results and this is my entire results over here okay now let me work along with chat promptly now see there is something called as prompt template and prompt template is like how you want your LM model to behave or what kind of response or what kind of role you really want to give your LLM model I can say hey act as an AI engine and provide the suggestion to develop an amazing gen AI project right So that is the kind of rule I'm setting it to my LLM app itself LLM model it's okay you have to behave in the specific way and give me the answer right So similarly a language also supports different types of chat from template also right so that is what I'm actually going to show you so now we are going to discuss about chat prompt template so I have just shown you one way of calling this particular model we'll be discussing as we go ahead right now what I'm actually going to do over here I'll just go ahead and write from line chain okay line chain underscore core okay dot prompts okay dot prompts I'm sure import chat prompt now what is this chat prompt temper it we will discuss about chat prompt template it it is just like I can tell my LMA model hey you you have to behave something like this so let's say I will just go ahead and create a custom prompt so here I'll go ahead and write prompt is equal to chat prompt now here with respect to this prompt template I will be using one very important function which is called as prom messages and from this particular messages we will define our entire like what my LLM model needs to be right so here I can probably go ahead and create my list inside this list I will be giving in the form of tuples a key value pairs first thing when I go ahead and write a system I'm assigning some role to the system system basically means my element I say hey you are an expert AI engineer okay provide me answers based on the question okay something so this is a very simple role that I'm giving to my system my LMM model saying that hey you are an expert AI engineer okay so please go ahead and provide me some answers based on the questions that I have right so this is one very important thing now the this is for the system but what with respect to the users right so here I'll go ahead and write user comma and here I'll say hey user will provide you some inputs okay this input is just like a placeholder okay this input is just like a placeholder like usually is asking you any question then the system the LM model is basically an AIX engineer should provide with the answer based on the question provide like what my LLM model needs to be like right so here I can probably let's say I will just go ahead and create my custom prompt so here I'll go ahead and write prompt is equal to chat prompt template now here with respect to prompt template I will be using one very important function which is called as prompt messages we will define our entire like what my LLM model needs to be so here I can probably go ahead and create my list now inside this list I will be giving in the form of tuples my key value pairs first thing when I go ahead and write a system I'm assigning some role to the system system basically means my element I'll say hey you are an expert engineer okay provide me answers based on the question okay something like this so this is a very simple role that I'm giving to my system my LM model saying that hey you are an expert AI engineer okay so please go ahead and provide me some answers based on the questions that I have right so this is one very important thing now the this is for the system but what with respect to users right so here I'll go ahead and write user comma and here I'll say hey user will provide you some inputs okay this input is just like a placeholder okay this input just like a placeholder like user is asking you any question then the system the LM model is basically an AI and it should provide with an answer based on the question provided by the user or based on the questions okay and this is my type prompt template that I've actually created okay if I go ahead and just execute this and show you so this becomes my prompt prompt template my input variables as input and here input variables template is like you are an expert AI engineer providing the answer based on the questions right and it has also said that hey in the template also you have to consider input as your input variable itself right so all this information is there in that prompt but this is very much good to start right now what I can actually do right is that use this particular prompt template along with my LLM model right so what I will do I will first of all go ahead and create a chain and it is important because see my LLM model should know like what it has to behave like and that instruction is probably coming from here from this particular chart prompt template it has to behave like and that instruction is probably coming from here from the this particular chart from template so we will go ahead and create a chain so prompt slash LLM model right so when we do or like this this pipe sign right it's basically saying that hey we need to combine this prompt along and that actually becomes a chain now whenever I give an input first of all it will go through the prompt and then it will go to the LLM and finally we'll get the response right now in order to call this right chain so I'll just go ahead and write chain dot invoke now you know what is my input right so this is my key that I really need to pass because that is what I've actually set it over here in my prompt right I'll go ahead and say hey can you tell me let's say can you tell me about like smithsmith is useful for like what is Langsmith useful for? So I'm just asking a simple question over here that's important answer we'll be able to get and let me do one thing let me just go ahead and provide a variable which is called a response and then I will just go ahead and print this response display this response print this response whatever thing I really want so I'll just go ahead and print this response if I go ahead and execute it so here you'll be able to see that again the best thing will be that it'll the the entire thing will also be going towards the you'll be able to see that every everything is basically getting tracked in the length portal okay so here you can see certainly language with tool design to enhance the development all the answers you are specifically getting logging pasting everything all the answers you are actually getting over here based on the content that I'm actually getting responses okay now this is one basic example of probably creating chain so chain basically combine multiple things chain like prompt to combine LLM to create your own custom prompt and based on that and it just gives you an idea like how once the input is given by the user how the flow is you know initially go to the element and then that is how you'll be able to see it if I go ahead and see the type of response you'll be able to see that it is a kind of AI message that basically this response is basically coming from the AI message itself right so I hope you're able to understand it very much clearly now let's do one more thing see right now by default I'm getting some kind of message okay and I really want to make sure that I probably can use some kind of output parcel also to display my response so that is where one type of output passer the default output parser that we will be using is something called a string output parser okay now string output parser if I really want to give you an example you know and you'll be seeing in further sessions you know we will also making sure that our output parser is just like getting the message from the LLM and how you really want to display it okay by default there's a string output parser class but you can also create your own custom output parser okay and so for that we'll be seeing that how we can basically create this output parser so first of all what I will be doing I will be going ahead and importing from line chain so underscore code okay dot output parsers okay and then we are going to import st output parser now this output parser will be responsible in displaying my entire output so here I'm just going to go ahead and write output parser is equal to str output parser and here I'm initializing it now again I have to go ahead and create my chain this time first thing that I really want to pass is my prompt then I'll pass it to my ln then whatever response ln is basically giving it'll just go through this particular output parser which is nothing but it is my output parser variable that I've actually defined okay now see the magic what will specifically happen once I create this chain so here I will go ahead and print my response let us go ahead okay so I'm writing same thing chain dot invoke input can it tell me about Lang Smith print response let's go ahead and execute it and this time you'll be able to see my output parser and I'm able to get directly I don't have content so that is the reason I was showing you right that we are getting an error when I was able to execute by default setting out to pass whatever message you are specifically getting that is only going to get displayed right So it is always handy to use the string out to parse because based on your likes and dislikes you can actually display the output result in the upcoming videos will also be customizing this entire thing we'll be creating this particular class and we'll be doing more things okay so in short in this video we have used the most common and most basic and common component supply chain from template small now in my next video we'll create
# Out:
# AIMessage(content='Here\'s a 10-word summary of AI:\n\n"Artificial Intelligence (AI) is a computer system that thinks and learns."', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 42, 'total_tokens': 69, 'completion_time': 0.041151195, 'completion_tokens_details': None, 'prompt_time': 0.002782008, 'prompt_tokens_details': None, 'queue_time': 0.050963782, 'total_time': 0.043933203}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fb284-0c77-70c1-8860-a5e535f7b431-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 27, 'total_tokens': 69})

# %%
# DATA INGESTION 
from langchain_docling.loader import DoclingLoader
FILE_PATH = "https://en.wikipedia.org/wiki/History_of_India"

loader = DoclingLoader(file_path = FILE_PATH)
docs=loader.load()

# %%
# DATA TRANSFORMATION 
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 300 , chunk_overlap = 20)
documents = text_splitter.split_documents(docs)
documents

# %%
#EMBEDDING HUGGINGFACE
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    encode_kwargs={"normalize_embeddings": True},
)

query_result = embeddings.embed_query()
# Out:
# e:\pdho wp AI\Langchain\.venv\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Aviral\.cache\huggingface\hub\models--BAAI--bge-base-en-v1.5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 3554.75it/s]
# ...
